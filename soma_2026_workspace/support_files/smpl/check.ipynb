# %%
import pickle

# 💡 请将下方路径替换为你存放 gmm_08.pkl 的真实绝对路径
gmm_path = '/home/u3625378/soma_2026_workspace/support_files/smpl/pose_body_prior.pkl'

with open(gmm_path, 'rb') as f:
    # 使用 latin-1 编码读取（底层的 moshpp 也是用这个编码读取的）
    gmm_data = pickle.load(f, encoding='latin-1')

print("--- 🎉 成功读取 GMM 字典！ ---")
print("字典里的键有:", gmm_data.keys())
print("均值矩阵 (means) 的形状:", gmm_data['means'].shape)
print("协方差矩阵 (covars) 的 shape:", gmm_data['covars'].shape)
print("权重矩阵 (weights) 的 shape:", gmm_data['weights'].shape)
# Out:
# --- 🎉 成功读取 GMM 字典！ ---
# 字典里的键有: dict_keys(['covars', 'weights', 'means'])
# 均值矩阵 (means) 的形状: (8, 69)
# 协方差矩阵 (covars) 的 shape: (8, 69, 69)
# 权重矩阵 (weights) 的 shape: (8,)
