# %% [markdown]
# # Solving MoCap Sequences
# It might be the case that you have an already labeled mocap dataset and you want to simply "mosh" it.
# Here we take
# [SOMA dataset's manually labeled mocaps](https://download.is.tue.mpg.de/download.php?domain=soma&sfile=evaluation_mocaps/original/SOMA_dataset/SOMA_manual_labeled.tar.bz2)
# as a sample case study and provide a code snippet to just mosh it.
# Please have in mind that we can also process your mocaps for you in case you agree to release them under
# [AMASS](https://amass.is.tue.mpg.de/)
# for research purposes.
#
# Furthermore, note that our goal is to simply mosh a dataset without considering comparability with other mosh runs;
# i.e. you cannot compare these results with SOMA experiments. For that refer to special mosh run presented in
# [here](run_soma_on_soma_dataset.ipynb).
#
# Finally, the same code can be used for rendering the MoSh results as well. Enjoy!

# %%
import os.path as osp
from glob import glob

import numpy as np
from loguru import logger

from soma.amass.mosh_manual import mosh_manual

# %%
soma_work_base_dir = '/home/u3625378/soma_2026_workspace'
support_base_dir = osp.join(soma_work_base_dir, 'support_files')

mocap_base_dir = osp.join(soma_work_base_dir, 'data')

work_base_dir = osp.join(soma_work_base_dir, 'runtime_mosh')

target_ds_names = ['Boss_01']

for ds_name in target_ds_names:
    mocap_fnames = glob(osp.join(mocap_base_dir, ds_name,  '*/*.c3d'))

    logger.info(f'#mocaps found for {ds_name}: {len(mocap_fnames)}')
    mosh_manual(
        mocap_fnames,
        mosh_cfg={
            'moshpp.verbosity': 1, 
            'dirs.work_base_dir': osp.join(work_base_dir, 'mosh_results'),
            'dirs.support_base_dir': support_base_dir,           
        },

        render_cfg={
            'dirs.work_base_dir': osp.join(work_base_dir, 'mp4_renders'),
            'render.render_engine': 'eevee',  # eevee / cycles,
            # 'render.render_engine': 'cycles',  # eevee / cycles,
            'render.show_markers': True,
            # 'render.save_final_blend_file': True
            'dirs.support_base_dir': support_base_dir,

        },
        parallel_cfg={
            'pool_size': 1,
            'max_num_jobs': 100,
            'randomly_run_jobs': False,
        },
        run_tasks=[
            'mosh',
            # 'render',
        ],
        # fast_dev_run=True,
    )
# Out:
# Actor_01 -- Gallery_01 -- 1769070482:<module>:13 -- #mocaps found for Boss_01: 45
# Actor_01 -- Gallery_01 -- mosh_manual:mosh_manual:107 -- Submitting MoSh++ jobs.
# Actor_01 -- Gallery_01 -- parallel_tools:run_parallel_jobs:54 -- #Job(s) submitted: 1
# Actor_01 -- Gallery_01 -- parallel_tools:run_parallel_jobs:58 -- max_num_jobs is set to 100. choosing the first #Job(s): 1
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:__init__:95 -- mocap_fname: /home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-jumping_left-rep1.c3d
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:__init__:97 -- stagei_fname: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:__init__:98 -- stageii_fname: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/01-boss-jumping_left-rep1_stageii.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:__init__:103 -- surface_model: type: smplx; gender: neutral; fname:/home/u3625378/soma_2026_workspace/support_files/smplx/neutral/model.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:__init__:107 -- optimize_fingers: False, optimize_face: False, optimize_toes: False, optimize_betas: True, optimize_dynamics: False
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:prepare_stagei_frames:154 -- 12 subject specific mocap(s) are selected for mosh stagei.
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:prepare_stagei_frames:157 -- Selecting 12 frames using method random_strict on frames with 100% least_avail_markers
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:prepare_stagei_frames:197 -- Using frames for stage-i: ['/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-walking_clockwise-rep1.c3d_001568'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-squatting_left-rep2.c3d_000128'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-raising_hand_left-rep1.c3d_001366'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-raising_hand_left-rep1.c3d_000566'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-bending_down_left-rep1.c3d_000488'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-stand_left-rep1.c3d_000613'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-jumping_center-rep2.c3d_000519'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-bending_down_left-rep2.c3d_000449'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-bending_down_left-rep2.c3d_000507'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-raising_hand_right-rep1.c3d_000734'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-stand_left-rep1.c3d_000408'
#  '/home/u3625378/soma_2026_workspace/data/Boss_01/Actor_01/01-boss-shooting-rep1.c3d_001480']
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:mosh_stagei:240 -- Attempting mosh stagei to create /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:120 -- using marker_layout_fname: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Boss_01_smplx.json
# Actor_01 -- 01-boss-jumping_left-rep1 -- edit_tools:marker_layout_load:124 -- Assuming SMPLx for marker layout since surface_model_type field was not available in: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Boss_01_smplx.json
# Actor_01 -- 01-boss-jumping_left-rep1 -- edit_tools:marker_layout_load:130 -- Loading marker layout: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Boss_01_smplx.json
# Actor_01 -- 01-boss-jumping_left-rep1 -- edit_tools:marker_layout_load:134 -- Available marker types: {'ball': 24}. Total: 24 markers.
# Actor_01 -- 01-boss-jumping_left-rep1 -- bodymodel_loader:load_moshpp_models:93 -- Loading model: /home/u3625378/soma_2026_workspace/support_files/smplx/neutral/model.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:160 -- can_model.betas.shape: (400,)
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:161 -- opt_models[0].betas.shape: (400,)
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:180 -- Estimating for #latent markers: 24
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:217 -- Number of available markers in each stagei selected frames: (F00, 24), (F01, 24), (F02, 24), (F03, 24), (F04, 24), (F05, 24), (F06, 24), (F07, 24), (F08, 24), (F09, 24), (F10, 24), (F11, 24)
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:225 -- Rigidly aligning the body to the markers
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:250 -- MoSh stagei weights before annealing:
# stagei_wt_poseH: 3.0
# stagei_wt_poseF: 3.0
# stagei_wt_expr: 34.0
# stagei_wt_pose: 3.0
# stagei_wt_poseB: 3.0
# stagei_wt_init_finger_left: 400.0
# stagei_wt_init_finger_right: 400.0
# stagei_wt_init_finger: 400.0
# stagei_wt_betas: 10.0
# stagei_wt_init: 300
# stagei_wt_data: 75.0
# stagei_wt_surf: 10000.0
# stagei_wt_annealing: [1.0, 0.5, 0.25, 0.125]
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:254 -- head_marker_corr_fname is provided and is being loaded: /home/u3625378/soma_2026_workspace/support_files/ssm_head_marker_corr.npz
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:265 -- Not all of the head markers are available to take cov into account: (RFHD, False) -- (LFHD, False) -- (RBHD, False) -- (LBHD, False)
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:268 -- Beginning mosh stagei with opt_settings.weights_type: smplx
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:342 -- Step 1/4 : Opt. wt_anneal_factor = 1.00, wt_data = 1.00, wt_poseB = 143.75
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types ball = 300.00:
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 0.00e+00 | data = 1.62e+06 | init_ball = 7.21e-27 | poseB = 2.46e+04 | surf = 2.41e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:417 -- Final loss values: beta = 2.81e+03 | data = 9.29e+05 | init_ball = 3.33e+03 | poseB = 1.64e+04 | surf = 1.59e+02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:342 -- Step 2/4 : Opt. wt_anneal_factor = 0.50, wt_data = 0.50, wt_poseB = 287.50
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types ball = 150.00:
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 7.02e+02 | data = 3.72e+06 | init_ball = 8.33e+02 | poseB = 4.10e+03 | surf = 1.59e+02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:417 -- Final loss values: beta = 9.20e+02 | data = 3.71e+06 | init_ball = 9.40e+02 | poseB = 4.18e+03 | surf = 2.17e+02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:342 -- Step 3/4 : Opt. wt_anneal_factor = 0.25, wt_data = 0.25, wt_poseB = 575.00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types ball = 75.00:
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 2.30e+02 | data = 1.48e+07 | init_ball = 2.35e+02 | poseB = 1.05e+03 | surf = 2.17e+02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:417 -- Final loss values: beta = 2.53e+02 | data = 1.47e+07 | init_ball = 2.68e+02 | poseB = 1.06e+03 | surf = 2.38e+04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:342 -- Step 4/4 : Opt. wt_anneal_factor = 0.12, wt_data = 0.12, wt_poseB = 1150.00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types ball = 37.50:
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 6.33e+01 | data = 5.90e+07 | init_ball = 6.71e+01 | poseB = 2.64e+02 | surf = 2.38e+04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stagei:417 -- Final loss values: beta = 7.35e+01 | data = 5.77e+07 | init_ball = 1.26e+02 | poseB = 2.79e+02 | surf = 4.38e+05
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:mosh_stagei:257 -- created stagei_fname: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:mosh_stagei:259 -- finished mosh stagei in 0:11:20.124937
# /home/u3625378/miniconda3/envs/soma/lib/python3.7/site-packages/omegaconf/resolvers/oc/__init__.py:91: UserWarning: 'dirs.markerlyout_basename' is deprecated. Change your code and config to use 'dirs.marker_layout.basename'
#   warnings.warn(category=UserWarning, message=msg)
# /home/u3625378/miniconda3/envs/soma/lib/python3.7/site-packages/omegaconf/resolvers/oc/__init__.py:91: UserWarning: 'dirs.marker_layout_fname' is deprecated. Change your code and config to use 'dirs.marker_layout.fname'
#   warnings.warn(category=UserWarning, message=msg)
# betas shape: torch.Size([1, 16])
# shapedirs shape: torch.Size([10475, 3, 16])
# v_template shape: torch.Size([1, 10475, 3])
# No radius found for ball
# Actor_01 -- 01-boss-jumping_left-rep1 -- edit_tools:marker_layout_load:130 -- Loading marker layout: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.json
# Actor_01 -- 01-boss-jumping_left-rep1 -- edit_tools:marker_layout_load:134 -- Available marker types: {'ball': 24}. Total: 24 markers.
# betas shape: torch.Size([1, 10])
# shapedirs shape: torch.Size([10475, 3, 10])
# v_template shape: torch.Size([1, 10475, 3])
# No radius found for ball
# Actor_01 -- 01-boss-jumping_left-rep1 -- edit_tools:marker_layout_load:130 -- Loading marker layout: /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.json
# Actor_01 -- 01-boss-jumping_left-rep1 -- edit_tools:marker_layout_load:134 -- Available marker types: {'ball': 24}. Total: 24 markers.
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:dump_stagei_marker_layout:338 -- created /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.json
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:dump_stagei_marker_layout:339 -- created /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.ply
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:dump_stagei_marker_layout:340 -- created /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/neutral_stagei.c3d
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:run_moshpp_once:600 -- Final mosh stagei loss: data = 3.33e+15 | poseB = 7.81e+04 | init_ball = 1.59e+04 | beta = 5.40e+03 | surf = 1.91e+11
# Actor_01 -- 01-boss-jumping_left-rep1 -- mosh_head:mosh_stageii:277 -- attempting mosh stageii to create /home/u3625378/soma_2026_workspace/runtime_mosh/mosh_results/Boss_01/Actor_01/01-boss-jumping_left-rep1_stageii.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:473 -- Loaded mocap markers for mosh stageii
# Actor_01 -- 01-boss-jumping_left-rep1 -- bodymodel_loader:load_moshpp_models:93 -- Loading model: /home/u3625378/soma_2026_workspace/support_files/smplx/neutral/model.pkl
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:505 -- #observed, #simulated markers: 24, 24
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:533 -- mosh stageii weights are subject to change during the optimization, depending on how many markers are absent in each frame.
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:537 -- MoSh stagei weights before annealing:
# stageii_wt_data: 400
# stageii_wt_velo: 2.5
# stageii_wt_dmpl: 1.0
# stageii_wt_expr: 1.0
# stageii_wt_poseB: 1.6
# stageii_wt_poseH: 1.0
# stageii_wt_poseF: 1.0
# stageii_wt_annealing: 2.5
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:541 -- Starting mosh stageii for 554 frames.
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:631 -- Rigidly aligning the markers to the body...
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0000/0554 -- Step 1. initial loss values: data = 3.74e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0000/0554 -- Step 1. final loss values: data = 3.73e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0000/0554 -- Step 2. initial loss values: data = 3.73e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0000/0554 -- Step 2. final loss values: data = 3.73e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0001/0554 -- Step 1. initial loss values: data = 3.73e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0001/0554 -- Step 1. final loss values: data = 3.72e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0001/0554 -- Step 2. initial loss values: data = 3.72e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0001/0554 -- Step 2. final loss values: data = 3.72e+04 | poseB = 3.36e+03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0002/0554 -- Step 1. initial loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 2.22e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0002/0554 -- Step 1. final loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 2.22e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0002/0554 -- Step 2. initial loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 2.22e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0002/0554 -- Step 2. final loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 2.19e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0003/0554 -- Step 1. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 7.06e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0003/0554 -- Step 1. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 2.27e-07
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0003/0554 -- Step 2. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 2.27e-07
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0003/0554 -- Step 2. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 3.70e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0004/0554 -- Step 1. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 1.09e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0004/0554 -- Step 1. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 8.21e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0004/0554 -- Step 2. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 8.21e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0004/0554 -- Step 2. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 1.15e-09
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0005/0554 -- Step 1. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 1.63e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0005/0554 -- Step 1. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 6.82e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0005/0554 -- Step 2. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 6.82e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0005/0554 -- Step 2. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 9.14e-10
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0006/0554 -- Step 1. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 2.32e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0006/0554 -- Step 1. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 5.44e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0006/0554 -- Step 2. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 5.44e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0006/0554 -- Step 2. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 4.61e-10
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0007/0554 -- Step 1. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 2.98e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0007/0554 -- Step 1. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 5.22e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0007/0554 -- Step 2. initial loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 5.22e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0007/0554 -- Step 2. final loss values: data = 3.71e+04 | poseB = 3.36e+03 | velo = 2.68e-10
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0008/0554 -- Step 1. initial loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 3.51e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0008/0554 -- Step 1. final loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 5.38e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0008/0554 -- Step 2. initial loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 5.38e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0008/0554 -- Step 2. final loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 7.55e-11
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0009/0554 -- Step 1. initial loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 3.80e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0009/0554 -- Step 1. final loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 5.50e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0009/0554 -- Step 2. initial loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 5.50e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0009/0554 -- Step 2. final loss values: data = 3.72e+04 | poseB = 3.36e+03 | velo = 1.75e-11
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0010/0554 -- Step 1. initial loss values: data = 3.73e+04 | poseB = 3.36e+03 | velo = 3.86e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0010/0554 -- Step 1. final loss values: data = 3.72e+04 | poseB = 3.43e+03 | velo = 1.56e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0010/0554 -- Step 2. initial loss values: data = 3.72e+04 | poseB = 3.43e+03 | velo = 1.56e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0010/0554 -- Step 2. final loss values: data = 3.68e+04 | poseB = 3.51e+03 | velo = 3.73e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0011/0554 -- Step 1. initial loss values: data = 3.67e+04 | poseB = 3.51e+03 | velo = 3.73e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0011/0554 -- Step 1. final loss values: data = 3.63e+04 | poseB = 3.64e+03 | velo = 2.49e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0011/0554 -- Step 2. initial loss values: data = 3.63e+04 | poseB = 3.64e+03 | velo = 2.49e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0011/0554 -- Step 2. final loss values: data = 3.61e+04 | poseB = 3.71e+03 | velo = 2.25e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0012/0554 -- Step 1. initial loss values: data = 3.60e+04 | poseB = 3.71e+03 | velo = 5.40e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0012/0554 -- Step 1. final loss values: data = 3.58e+04 | poseB = 3.79e+03 | velo = 1.18e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0012/0554 -- Step 2. initial loss values: data = 3.58e+04 | poseB = 3.79e+03 | velo = 1.18e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0012/0554 -- Step 2. final loss values: data = 3.56e+04 | poseB = 3.85e+03 | velo = 2.27e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0013/0554 -- Step 1. initial loss values: data = 3.55e+04 | poseB = 3.85e+03 | velo = 3.73e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0013/0554 -- Step 1. final loss values: data = 3.52e+04 | poseB = 3.90e+03 | velo = 2.05e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0013/0554 -- Step 2. initial loss values: data = 3.52e+04 | poseB = 3.90e+03 | velo = 2.05e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0013/0554 -- Step 2. final loss values: data = 3.43e+04 | poseB = 3.91e+03 | velo = 1.94e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0014/0554 -- Step 1. initial loss values: data = 3.42e+04 | poseB = 3.91e+03 | velo = 1.46e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0014/0554 -- Step 1. final loss values: data = 3.42e+04 | poseB = 3.91e+03 | velo = 1.47e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0014/0554 -- Step 2. initial loss values: data = 3.42e+04 | poseB = 3.91e+03 | velo = 1.47e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0014/0554 -- Step 2. final loss values: data = 3.41e+04 | poseB = 3.91e+03 | velo = 1.48e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0015/0554 -- Step 1. initial loss values: data = 3.41e+04 | poseB = 3.91e+03 | velo = 1.51e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0015/0554 -- Step 1. final loss values: data = 3.40e+04 | poseB = 3.91e+03 | velo = 3.76e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0015/0554 -- Step 2. initial loss values: data = 3.40e+04 | poseB = 3.91e+03 | velo = 3.76e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0015/0554 -- Step 2. final loss values: data = 3.40e+04 | poseB = 3.91e+03 | velo = 3.39e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0016/0554 -- Step 1. initial loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 1.53e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0016/0554 -- Step 1. final loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 1.17e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0016/0554 -- Step 2. initial loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 1.17e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0016/0554 -- Step 2. final loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 1.15e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0017/0554 -- Step 1. initial loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 2.69e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0017/0554 -- Step 1. final loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 2.38e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0017/0554 -- Step 2. initial loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 2.38e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0017/0554 -- Step 2. final loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 2.10e-05
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0018/0554 -- Step 1. initial loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 3.72e-07
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0018/0554 -- Step 1. final loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 2.85e-07
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0018/0554 -- Step 2. initial loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 2.85e-07
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0018/0554 -- Step 2. final loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 2.10e-07
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0019/0554 -- Step 1. initial loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 2.33e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0019/0554 -- Step 1. final loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 1.78e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0019/0554 -- Step 2. initial loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 1.78e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0019/0554 -- Step 2. final loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 1.31e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0020/0554 -- Step 1. initial loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 1.45e-09
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0020/0554 -- Step 1. final loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 3.65e-10
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0020/0554 -- Step 2. initial loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 3.65e-10
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0020/0554 -- Step 2. final loss values: data = 3.38e+04 | poseB = 3.91e+03 | velo = 1.75e-12
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0021/0554 -- Step 1. initial loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 1.45e-09
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0021/0554 -- Step 1. final loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 1.11e-09
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0021/0554 -- Step 2. initial loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 1.11e-09
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0021/0554 -- Step 2. final loss values: data = 3.39e+04 | poseB = 3.91e+03 | velo = 8.19e-10
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0022/0554 -- Step 1. initial loss values: data = 3.41e+04 | poseB = 3.91e+03 | velo = 9.09e-11
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0022/0554 -- Step 1. final loss values: data = 3.41e+04 | poseB = 3.91e+03 | velo = 6.96e-11
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0022/0554 -- Step 2. initial loss values: data = 3.41e+04 | poseB = 3.91e+03 | velo = 6.96e-11
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0022/0554 -- Step 2. final loss values: data = 3.41e+04 | poseB = 3.91e+03 | velo = 6.48e-11
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0023/0554 -- Step 1. initial loss values: data = 3.44e+04 | poseB = 3.91e+03 | velo = 2.22e-12
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0023/0554 -- Step 1. final loss values: data = 3.44e+04 | poseB = 3.91e+03 | velo = 2.01e-12
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0023/0554 -- Step 2. initial loss values: data = 3.44e+04 | poseB = 3.91e+03 | velo = 2.01e-12
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0023/0554 -- Step 2. final loss values: data = 3.44e+04 | poseB = 3.91e+03 | velo = 1.84e-12
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0024/0554 -- Step 1. initial loss values: data = 3.50e+04 | poseB = 3.91e+03 | velo = 2.08e-14
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0024/0554 -- Step 1. final loss values: data = 3.50e+04 | poseB = 3.91e+03 | velo = 6.37e-14
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0024/0554 -- Step 2. initial loss values: data = 3.50e+04 | poseB = 3.91e+03 | velo = 6.37e-14
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0024/0554 -- Step 2. final loss values: data = 3.50e+04 | poseB = 3.91e+03 | velo = 6.89e-14
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0025/0554 -- Step 1. initial loss values: data = 3.57e+04 | poseB = 3.91e+03 | velo = 9.75e-14
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0025/0554 -- Step 1. final loss values: data = 3.57e+04 | poseB = 3.91e+03 | velo = 7.07e-14
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0025/0554 -- Step 2. initial loss values: data = 3.57e+04 | poseB = 3.91e+03 | velo = 7.07e-14
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0025/0554 -- Step 2. final loss values: data = 3.40e+04 | poseB = 3.94e+03 | velo = 1.54e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0026/0554 -- Step 1. initial loss values: data = 3.48e+04 | poseB = 3.94e+03 | velo = 1.54e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0026/0554 -- Step 1. final loss values: data = 3.45e+04 | poseB = 3.94e+03 | velo = 1.56e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0026/0554 -- Step 2. initial loss values: data = 3.45e+04 | poseB = 3.94e+03 | velo = 1.56e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0026/0554 -- Step 2. final loss values: data = 3.43e+04 | poseB = 3.94e+03 | velo = 1.58e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0027/0554 -- Step 1. initial loss values: data = 3.54e+04 | poseB = 3.94e+03 | velo = 1.48e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0027/0554 -- Step 1. final loss values: data = 3.53e+04 | poseB = 3.94e+03 | velo = 3.63e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0027/0554 -- Step 2. initial loss values: data = 3.53e+04 | poseB = 3.94e+03 | velo = 3.63e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0027/0554 -- Step 2. final loss values: data = 3.53e+04 | poseB = 3.94e+03 | velo = 2.03e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0028/0554 -- Step 1. initial loss values: data = 3.68e+04 | poseB = 3.94e+03 | velo = 5.96e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0028/0554 -- Step 1. final loss values: data = 3.68e+04 | poseB = 3.94e+03 | velo = 5.38e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0028/0554 -- Step 2. initial loss values: data = 3.68e+04 | poseB = 3.94e+03 | velo = 5.38e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0028/0554 -- Step 2. final loss values: data = 3.68e+04 | poseB = 3.94e+03 | velo = 4.83e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0029/0554 -- Step 1. initial loss values: data = 3.90e+04 | poseB = 3.94e+03 | velo = 5.96e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0029/0554 -- Step 1. final loss values: data = 3.90e+04 | poseB = 3.94e+03 | velo = 1.50e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0029/0554 -- Step 2. initial loss values: data = 3.90e+04 | poseB = 3.94e+03 | velo = 1.50e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0029/0554 -- Step 2. final loss values: data = 3.90e+04 | poseB = 3.94e+03 | velo = 8.49e-07
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0030/0554 -- Step 1. initial loss values: data = 4.20e+04 | poseB = 3.94e+03 | velo = 2.33e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0030/0554 -- Step 1. final loss values: data = 4.20e+04 | poseB = 3.94e+03 | velo = 2.10e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0030/0554 -- Step 2. initial loss values: data = 4.20e+04 | poseB = 3.94e+03 | velo = 2.10e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0030/0554 -- Step 2. final loss values: data = 4.20e+04 | poseB = 3.94e+03 | velo = 1.89e-06
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0031/0554 -- Step 1. initial loss values: data = 4.60e+04 | poseB = 3.94e+03 | velo = 2.33e-08
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0031/0554 -- Step 1. final loss values: data = 3.47e+04 | poseB = 3.49e+03 | velo = 3.38e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0031/0554 -- Step 2. initial loss values: data = 3.47e+04 | poseB = 3.49e+03 | velo = 3.38e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0031/0554 -- Step 2. final loss values: data = 3.48e+04 | poseB = 3.47e+03 | velo = 3.23e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0032/0554 -- Step 1. initial loss values: data = 3.50e+04 | poseB = 3.47e+03 | velo = 3.23e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0032/0554 -- Step 1. final loss values: data = 3.45e+04 | poseB = 3.28e+03 | velo = 2.82e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0032/0554 -- Step 2. initial loss values: data = 3.45e+04 | poseB = 3.28e+03 | velo = 2.82e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0032/0554 -- Step 2. final loss values: data = 3.05e+04 | poseB = 2.46e+03 | velo = 6.33e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0033/0554 -- Step 1. initial loss values: data = 3.04e+04 | poseB = 2.46e+03 | velo = 2.76e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0033/0554 -- Step 1. final loss values: data = 2.97e+04 | poseB = 2.54e+03 | velo = 2.51e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0033/0554 -- Step 2. initial loss values: data = 2.97e+04 | poseB = 2.54e+03 | velo = 2.51e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0033/0554 -- Step 2. final loss values: data = 2.96e+04 | poseB = 2.58e+03 | velo = 2.60e+01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0034/0554 -- Step 1. initial loss values: data = 2.98e+04 | poseB = 2.58e+03 | velo = 2.43e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0034/0554 -- Step 1. final loss values: data = 2.92e+04 | poseB = 2.57e+03 | velo = 2.13e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0034/0554 -- Step 2. initial loss values: data = 2.92e+04 | poseB = 2.57e+03 | velo = 2.13e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0034/0554 -- Step 2. final loss values: data = 2.91e+04 | poseB = 2.56e+03 | velo = 2.93e+00
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0035/0554 -- Step 1. initial loss values: data = 2.94e+04 | poseB = 2.56e+03 | velo = 2.53e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0035/0554 -- Step 1. final loss values: data = 2.88e+04 | poseB = 2.51e+03 | velo = 1.70e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0035/0554 -- Step 2. initial loss values: data = 2.88e+04 | poseB = 2.51e+03 | velo = 1.70e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0035/0554 -- Step 2. final loss values: data = 2.88e+04 | poseB = 2.49e+03 | velo = 6.71e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0036/0554 -- Step 1. initial loss values: data = 2.91e+04 | poseB = 2.49e+03 | velo = 3.22e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0036/0554 -- Step 1. final loss values: data = 2.87e+04 | poseB = 2.43e+03 | velo = 4.29e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0036/0554 -- Step 2. initial loss values: data = 2.87e+04 | poseB = 2.43e+03 | velo = 4.29e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0036/0554 -- Step 2. final loss values: data = 2.87e+04 | poseB = 2.43e+03 | velo = 4.31e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0037/0554 -- Step 1. initial loss values: data = 2.91e+04 | poseB = 2.43e+03 | velo = 1.89e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0037/0554 -- Step 1. final loss values: data = 2.87e+04 | poseB = 2.38e+03 | velo = 5.65e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0037/0554 -- Step 2. initial loss values: data = 2.87e+04 | poseB = 2.38e+03 | velo = 5.65e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0037/0554 -- Step 2. final loss values: data = 2.87e+04 | poseB = 2.38e+03 | velo = 5.64e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0038/0554 -- Step 1. initial loss values: data = 2.91e+04 | poseB = 2.38e+03 | velo = 1.36e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0038/0554 -- Step 1. final loss values: data = 2.88e+04 | poseB = 2.33e+03 | velo = 4.47e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0038/0554 -- Step 2. initial loss values: data = 2.88e+04 | poseB = 2.33e+03 | velo = 4.47e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0038/0554 -- Step 2. final loss values: data = 2.88e+04 | poseB = 2.33e+03 | velo = 4.34e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0039/0554 -- Step 1. initial loss values: data = 2.92e+04 | poseB = 2.33e+03 | velo = 1.37e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0039/0554 -- Step 1. final loss values: data = 2.90e+04 | poseB = 2.31e+03 | velo = 5.90e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0039/0554 -- Step 2. initial loss values: data = 2.90e+04 | poseB = 2.31e+03 | velo = 5.90e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0039/0554 -- Step 2. final loss values: data = 2.90e+04 | poseB = 2.31e+03 | velo = 5.77e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0040/0554 -- Step 1. initial loss values: data = 2.94e+04 | poseB = 2.31e+03 | velo = 9.11e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0040/0554 -- Step 1. final loss values: data = 2.92e+04 | poseB = 2.29e+03 | velo = 5.94e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0040/0554 -- Step 2. initial loss values: data = 2.92e+04 | poseB = 2.29e+03 | velo = 5.94e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0040/0554 -- Step 2. final loss values: data = 2.92e+04 | poseB = 2.28e+03 | velo = 3.47e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0041/0554 -- Step 1. initial loss values: data = 2.95e+04 | poseB = 2.28e+03 | velo = 7.80e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0041/0554 -- Step 1. final loss values: data = 2.94e+04 | poseB = 2.28e+03 | velo = 2.67e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0041/0554 -- Step 2. initial loss values: data = 2.94e+04 | poseB = 2.28e+03 | velo = 2.67e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0041/0554 -- Step 2. final loss values: data = 2.94e+04 | poseB = 2.28e+03 | velo = 2.56e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0042/0554 -- Step 1. initial loss values: data = 2.97e+04 | poseB = 2.28e+03 | velo = 4.64e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0042/0554 -- Step 1. final loss values: data = 2.96e+04 | poseB = 2.29e+03 | velo = 1.66e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0042/0554 -- Step 2. initial loss values: data = 2.96e+04 | poseB = 2.29e+03 | velo = 1.66e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0042/0554 -- Step 2. final loss values: data = 2.96e+04 | poseB = 2.29e+03 | velo = 1.78e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0043/0554 -- Step 1. initial loss values: data = 2.98e+04 | poseB = 2.29e+03 | velo = 4.44e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0043/0554 -- Step 1. final loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 2.94e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0043/0554 -- Step 2. initial loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 2.94e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0043/0554 -- Step 2. final loss values: data = 2.97e+04 | poseB = 2.29e+03 | velo = 1.14e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0044/0554 -- Step 1. initial loss values: data = 2.99e+04 | poseB = 2.29e+03 | velo = 2.63e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0044/0554 -- Step 1. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 5.67e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0044/0554 -- Step 2. initial loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 5.67e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0044/0554 -- Step 2. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 3.70e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0045/0554 -- Step 1. initial loss values: data = 2.99e+04 | poseB = 2.30e+03 | velo = 2.18e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0045/0554 -- Step 1. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 6.51e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0045/0554 -- Step 2. initial loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 6.51e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0045/0554 -- Step 2. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 5.81e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0046/0554 -- Step 1. initial loss values: data = 2.99e+04 | poseB = 2.30e+03 | velo = 2.23e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0046/0554 -- Step 1. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 1.28e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0046/0554 -- Step 2. initial loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 1.28e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0046/0554 -- Step 2. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 2.34e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0047/0554 -- Step 1. initial loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 1.79e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0047/0554 -- Step 1. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 1.86e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0047/0554 -- Step 2. initial loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 1.86e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0047/0554 -- Step 2. final loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 8.97e-04
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0048/0554 -- Step 1. initial loss values: data = 2.98e+04 | poseB = 2.30e+03 | velo = 1.76e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0048/0554 -- Step 1. final loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 5.47e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0048/0554 -- Step 2. initial loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 5.47e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0048/0554 -- Step 2. final loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 1.21e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0049/0554 -- Step 1. initial loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 1.87e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0049/0554 -- Step 1. final loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 1.76e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0049/0554 -- Step 2. initial loss values: data = 2.97e+04 | poseB = 2.30e+03 | velo = 1.76e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0049/0554 -- Step 2. final loss values: data = 2.96e+04 | poseB = 2.30e+03 | velo = 1.17e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0050/0554 -- Step 1. initial loss values: data = 2.96e+04 | poseB = 2.30e+03 | velo = 1.60e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0050/0554 -- Step 1. final loss values: data = 2.96e+04 | poseB = 2.30e+03 | velo = 5.55e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0050/0554 -- Step 2. initial loss values: data = 2.96e+04 | poseB = 2.30e+03 | velo = 5.55e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0050/0554 -- Step 2. final loss values: data = 2.95e+04 | poseB = 2.30e+03 | velo = 1.62e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0051/0554 -- Step 1. initial loss values: data = 2.95e+04 | poseB = 2.30e+03 | velo = 1.99e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0051/0554 -- Step 1. final loss values: data = 2.94e+04 | poseB = 2.30e+03 | velo = 3.22e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0051/0554 -- Step 2. initial loss values: data = 2.94e+04 | poseB = 2.30e+03 | velo = 3.22e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0051/0554 -- Step 2. final loss values: data = 2.94e+04 | poseB = 2.30e+03 | velo = 6.57e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0052/0554 -- Step 1. initial loss values: data = 2.93e+04 | poseB = 2.30e+03 | velo = 4.30e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0052/0554 -- Step 1. final loss values: data = 2.93e+04 | poseB = 2.30e+03 | velo = 6.35e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0052/0554 -- Step 2. initial loss values: data = 2.93e+04 | poseB = 2.30e+03 | velo = 6.35e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0052/0554 -- Step 2. final loss values: data = 2.93e+04 | poseB = 2.30e+03 | velo = 3.61e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0053/0554 -- Step 1. initial loss values: data = 2.92e+04 | poseB = 2.30e+03 | velo = 1.40e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0053/0554 -- Step 1. final loss values: data = 2.92e+04 | poseB = 2.30e+03 | velo = 3.99e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0053/0554 -- Step 2. initial loss values: data = 2.92e+04 | poseB = 2.30e+03 | velo = 3.99e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0053/0554 -- Step 2. final loss values: data = 2.92e+04 | poseB = 2.30e+03 | velo = 2.12e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0054/0554 -- Step 1. initial loss values: data = 2.90e+04 | poseB = 2.30e+03 | velo = 1.26e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0054/0554 -- Step 1. final loss values: data = 2.90e+04 | poseB = 2.30e+03 | velo = 1.24e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:702 -- 0054/0554 -- Step 2. initial loss values: data = 2.90e+04 | poseB = 2.30e+03 | velo = 1.24e-01
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:707 -- 0054/0554 -- Step 2. final loss values: data = 2.90e+04 | poseB = 2.31e+03 | velo = 2.05e-03
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:663 -- 0055/0554 -- Step 1. initial loss values: data = 2.89e+04 | poseB = 2.31e+03 | velo = 1.67e-02
# Actor_01 -- 01-boss-jumping_left-rep1 -- chmosh:mosh_stageii:673 -- 0055/0554 -- Step 1. final loss values: data = 2.89e+04 | poseB = 2.31e+03 | velo = 3.77e-01
# ...
#     407     callback()
#     408     state.updateJ(obj)
# --> 409     state.r = obj.r
#     410
#     411     def stop(msg):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/optimization_internal.py in compute_r(self)
#      30             self.fevals = 0
#      31         self.fevals += 1
# ---> 32         return self.obj.r.ravel()
#      33
#      34     def dr_wrt(self, wrt, profiler=None):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#     374
#     375     def compute_r(self):
# --> 376         return np.concatenate([t.r for t in self.our_terms], axis=self.axis)
#     377
#     378     @property
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in <listcomp>(.0)
#     374
#     375     def compute_r(self):
# --> 376         return np.concatenate([t.r for t in self.our_terms], axis=self.axis)
#     377
#     378     @property
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#     169
#     170     def compute_r(self):
# --> 171         return self.a.r.reshape(self.newshape)
#     172
#     173     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     706
#     707     def compute_r(self):
# --> 708         return self.a.r * self.b.r
#     709
#     710     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     564
#     565     def compute_r(self):
# --> 566         return self.a.r - self.b.r
#     567
#     568     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#     374
#     375     def compute_r(self):
# --> 376         return np.concatenate([t.r for t in self.our_terms], axis=self.axis)
#     377
#     378     @property
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in <listcomp>(.0)
#     374
#     375     def compute_r(self):
# --> 376         return np.concatenate([t.r for t in self.our_terms], axis=self.axis)
#     377
#     378     @property
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#     308
#     309     def compute_r(self):
# --> 310         xr = self.x.r
#     311         if self.ndims == 1:
#     312             target_shape = np.atleast_1d(xr).shape
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     592     @property
#     593     def r(self):
# --> 594         self._call_on_changed()
#     595         if self._cache['r'] is None:
#     596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in _call_on_changed(self)
#     587
#     588         if len(self._dirty_vars) > 0:
# --> 589             self.on_changed(self._dirty_vars)
#     590             object.__setattr__(self, '_dirty_vars', set())
#     591
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in on_changed(self, which)
#     298     def on_changed(self, which):
#     299         if hasattr(self, '_dr_cached'):
# --> 300             if 'idxs' in which or self.a.r.size != self._dr_cached.shape[1]:
#     301                 del self._dr_cached
#     302
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     592     @property
#     593     def r(self):
# --> 594         self._call_on_changed()
#     595         if self._cache['r'] is None:
#     596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in _call_on_changed(self)
#     587
#     588         if len(self._dirty_vars) > 0:
# --> 589             self.on_changed(self._dirty_vars)
#     590             object.__setattr__(self, '_dirty_vars', set())
#     591
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/moshpp-3.0-py3.7.egg/moshpp/transformed_lm.py in on_changed(self, which)
#     136         coeffs = self.transformed_coeffs
#     137
# --> 138         e1 = can_body[closest[:, 1]] - can_body[closest[:, 0]]
#     139         e2 = can_body[closest[:, 2]] - can_body[closest[:, 0]]
#     140
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in __getitem__(self, key)
#     498
#     499     def __getitem__(self, key):
# --> 500         shape = self.shape
#     501         tmp = np.arange(np.prod(shape)).reshape(shape).__getitem__(key)
#     502         idxs = tmp.ravel()
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in shape(self)
#     315     @property
#     316     def shape(self):
# --> 317         return self.r.shape
#     318
#     319     @property
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/moshpp-3.0-py3.7.egg/moshpp/models/smpl_fast_derivatives.py in compute_r(self)
#     242
#     243     def compute_r(self):
# --> 244         return self._inner_model.r
#     245
#     246     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     548
#     549     def compute_r(self):
# --> 550         return self.a.r + self.b.r
#     551
#     552     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#     280
#     281     def compute_r(self):
# --> 282         result = self.a.r.ravel()[self.idxs].copy()
#     283         if hasattr(self, 'preferred_shape'):
#     284             return result.reshape(self.preferred_shape)
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#      34
#      35     def compute_r(self):
# ---> 36         return self.reorder(self.a.r)
#      37
#      38     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     548
#     549     def compute_r(self):
# --> 550         return self.a.r + self.b.r
#     551
#     552     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     548
#     549     def compute_r(self):
# --> 550         return self.a.r + self.b.r
#     551
#     552     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     548
#     549     def compute_r(self):
# --> 550         return self.a.r + self.b.r
#     551
#     552     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     706
#     707     def compute_r(self):
# --> 708         return self.a.r * self.b.r
#     709
#     710     def compute_dr_wrt(self, wrt):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#     280
#     281     def compute_r(self):
# --> 282         result = self.a.r.ravel()[self.idxs].copy()
#     283         if hasattr(self, 'preferred_shape'):
#     284             return result.reshape(self.preferred_shape)
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch_ops.py in compute_r(self)
#     729
#     730     def compute_r(self):
# --> 731         return self.a.r.dot(self.b.r)
#     732
#     733     def compute_d1(self):
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     594         self._call_on_changed()
#     595         if self._cache['r'] is None:
# --> 596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#     597             self._cache['rview'] = self._cache['r'].view()
#     598             self._cache['rview'].flags.writeable = False
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in compute_r(self)
#     374
#     375     def compute_r(self):
# --> 376         return np.concatenate([t.r for t in self.our_terms], axis=self.axis)
#     377
#     378     @property
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/reordering.py in <listcomp>(.0)
#     374
#     375     def compute_r(self):
# --> 376         return np.concatenate([t.r for t in self.our_terms], axis=self.axis)
#     377
#     378     @property
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in r(self)
#     592     @property
#     593     def r(self):
# --> 594         self._call_on_changed()
#     595         if self._cache['r'] is None:
#     596             self._cache['r'] = np.asarray(np.atleast_1d(self.compute_r()), dtype=np.float64, order='C')
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in _call_on_changed(self)
#     584             assert validity, msg
#     585         if hasattr(self, '_status'):
# --> 586             self._status = 'new'
#     587
#     588         if len(self._dirty_vars) > 0:
#
# ~/miniconda3/envs/soma/lib/python3.7/site-packages/chumpy/ch.py in __setattr__(self, name, value, itr)
#     359             setattr(self, k, self.__dict__[k])
#     360
# --> 361     def __setattr__(self, name, value, itr=None):
#     362         #print 'SETTING %s' % (name,)
#     363
#
# KeyboardInterrupt:

# %%
soma_work_base_dir = '/home/u3625378/soma_2026_workspace'
support_base_dir = osp.join(soma_work_base_dir, 'support_files')

mocap_base_dir = osp.join(soma_work_base_dir, 'data')

work_base_dir = osp.join(soma_work_base_dir, 'runtime_mosh')

target_ds_names = ['Boss_01']

for ds_name in target_ds_names:
    mocap_fnames = glob(osp.join(mocap_base_dir, ds_name,  '*/*.c3d'))

    logger.info(f'#mocaps found for {ds_name}: {len(mocap_fnames)}')
    mosh_manual(
        mocap_fnames,
        mosh_cfg={
            'moshpp.verbosity': 1, 
            'dirs.work_base_dir': osp.join(work_base_dir, 'mosh_results'),
            'dirs.support_base_dir': support_base_dir,           
        },

        render_cfg={
            'dirs.work_base_dir': osp.join(work_base_dir, 'mp4_renders'),
            'render.render_engine': 'eevee',  # eevee / cycles,
            # 'render.render_engine': 'cycles',  # eevee / cycles,
            'render.show_markers': True,
            # 'render.save_final_blend_file': True
            'dirs.support_base_dir': support_base_dir,

        },
        parallel_cfg={
            'pool_size': 1,
            'max_num_jobs': 100,
            'randomly_run_jobs': False,
        },
        run_tasks=[
            'mosh',
            # 'render',
        ],
        # fast_dev_run=True,
    )
